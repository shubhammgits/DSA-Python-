# %% [markdown]
# ## Nearest Available Drone

# %%
import math

# %%
drones = [[0,0,8],[2,2,9]]
target = [3,4]

def func(drones,target):
    n=len(drones)
    bestDistance = float('inf')
    ans= -1

    for i in range(n):
        X = drones[i][0]
        Y = drones[i][1]

        rng = drones[i][2]

        dist = abs(X-target[0]) + abs(Y-target[1])

        if dist<=drones[i:
            ans = dist

    return ans
    

func(drones,target)
# Out:
# -1

# %%
drones = [[0,0,8],[2,2,9]]
n=len(drones)

for i in range(n):
    X = drones[i][0]
    Y = drones[i][0]

    

    print(X,Y)
# Out:
# 0 0
# 2 2
