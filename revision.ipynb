# %%
a = [3,2,1,5,2]

largest = a[0]
for i in range(len(a)):
    if a[i] > largest:
        largest=a[i]

print(largest)
# Out:
# 5

# %%
a = [1,2,4,7,7,5]
largest = a[0]
secondL = -float('inf')

for i in range(1,len(a)):
    if a[i]>largest:
        secondL = largest
        largest = a[i]
    
    elif a[i] < largest and a[i] > secondL:
        secondL = a[i]
# Out:
# 4

# %%
7>7
# Out:
# False
