# %% [markdown]
# ## Minimum days to make 'm' bouqets

# %%
#brute:

arr = [7,7,7,7,13,11,12,7]
m = 2
k = 3

def possible(arr,day,m,k):
    cnt = 0
    n = len(arr)

    for i in range(n):
        if arr[i]<=day:
            cnt+=1
        else:
            noOfB += cnt/k
            cnt = 0

# %%
arr = [5,4,3,8]
n=len(arr)


temp1=[]
temp2=[]
temp1.append(arr[0])
temp2.append(arr[1])

for i in range(2,n):
    if temp1[-1]>temp2[-1]:
        temp1.append(arr[i])
    else:
        temp2.append(arr[i])
    
    
ans = temp1+temp2
print(ans)
# Out:
# [5, 3, 4, 8]
