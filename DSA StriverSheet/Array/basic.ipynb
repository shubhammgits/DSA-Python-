# %% [markdown]
# ## Arrays

# %%
import array as ar

# %%
arr = ar.array('i', [1,2,3,4,5])

# %%
type(arr)
# Out:
# array.array

# %%
print(arr)
print(arr[0])
arr.append(6)
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5, 6])
# 1
# array('i', [1, 2, 3, 4, 5, 6, 6])

# %%
arr[1:4]
# Out:
# array('i', [2, 3, 4])

# %%
a = [1,2,3,4,5]
for i in a:
    print(i, end=' ')
# Out:
# 1 2 3 4 5
