# %% [markdown]
# ## Two Sum Problem

# %%
#brute

arr=[2,6,5,8,11]
target=14
n=len(arr)

for i in range(0,n):
    for j in range(0,n):
        if i==j:
            continue

        if arr[i]+arr[j]==target:
            print(i,j)
# Out:
# 1 3
# 3 1
