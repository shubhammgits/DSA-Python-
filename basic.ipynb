# %%
print('Salman Khan')
# Out:
# Salman Khan

# %%
salmankahn = 'hello'
print(salmankahn)
# Out:
# hello

# %%
print('Heloo', True, 1.34, sep='/')
# Out:
# Heloo/True/1.34

# %%
print('Hello')
print('World')
# Out:
# Hello
# World

# %%
print('Hello', end='-')
print('World')
# Out:
# Hello-World

# %%
print(8)
print(1.45)
print(True)
print('Hello')
print([1,2,3,4,5])
print({'name' : 'Shubham', 'age' : 19, 'cgpa' : 9.1})
# Out:
# 8
# 1.45
# True
# Hello
# [1, 2, 3, 4, 5]
# {'name': 'Shubham', 'age': 19, 'cgpa': 9.1}

# %%
print(type(6+9j))
print(type(9.76))
print(type('Shubham'))
print(type('A'))
# Out:
# <class 'complex'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
name = 'Shubham'
a = 5
b = 10
print(f'Hello {name}, a+b = {a+b}')
# Out:
# Hello Shubham, a+b = 15

# %%
a = 5
print(a)
a='A'
print(a)
# Out:
# 5
# A

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c = 5
print(a,b,c)
# Out:
# 5 5 5

# %%
name  = input('Enter your name : ')
cgpa  = float(input('Enter your cgpa : '))

print(f'Hello {name}, your cgpa is {cgpa}.')
# Out:
# Hello Shubham, your cgpa is 8.0.

# %%
print(10.567 + 8)
# Out:
# 18.567

# %%
float(9)
# Out:
# 9.0

# %%
a = None
print(a)
# Out:
# None

# %%
print(4+5)
print(5-4)
print(5*4)
# Out:
# 9
# 1
# 20

# %%
print(9%6)
# Out:
# 3

# %%
print(9/6)
# Out:
# 1.5

# %%
print(9//6)
# Out:
# 1

# %%
print(1 and 0)
print(1 or 0)
print(not 1)
# Out:
# 0
# 1
# False

# %%
print(4 + '4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 print(4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(4 + int('4'))
# Out:
# 8

# %%
print(r'raw \n string')
# Out:
# raw \n string

# %%
print('raw \n string')
# Out:
# raw
#  string

# %%
a = 5
a+=4
print(a)
# Out:
# 9

# %%
str1 = 'shubham'
str2 = str1 + ' jha'
print(str2)
# Out:
# shubham jha
